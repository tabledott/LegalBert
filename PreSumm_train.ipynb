# %%
# https://stackoverflow.com/questions/45894212/installing-pyrouge-gets-error-in-ubuntu
# https://stackoverflow.com/questions/53581278/test-if-notebook-is-running-on-google-colab
# https://colab.research.google.com/github/antonysama/PreSumm/blob/master/pyrouge_install_oct6.ipynb#scrollTo=rBumfJ--eO2T

if not 'google.colab' in str(get_ipython()):
  raise

# !apt install libxml-parser-perl
# !git clone https://github.com/bheinzerling/pyrouge
# %cd pyrouge
# !python setup.py install
# !git clone https://github.com/andersjo/pyrouge.git rouge
# !pyrouge_set_rouge_path /content/pyrouge/rouge/tools/ROUGE-1.5.5/
# %cd rouge/tools/ROUGE-1.5.5/data
# %mv WordNet-2.0.exc.db WordNet-2.0.exc.db.orig
# !perl WordNet-2.0-Exceptions/buildExeptionDB.pl ./WordNet-2.0-Exceptions ./smart_common_words.txt ./WordNet-2.0.exc.db
# !python -m pyrouge.test
# %cd /content
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libxml-parser-perl is already the newest version (2.44-2build3).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# fatal: destination path 'pyrouge' already exists and is not an empty directory.
# /content/pyrouge
# running install
# running bdist_egg
# running egg_info
# writing pyrouge.egg-info/PKG-INFO
# writing dependency_links to pyrouge.egg-info/dependency_links.txt
# writing top-level names to pyrouge.egg-info/top_level.txt
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pyrouge
# creating build/bdist.linux-x86_64/egg/pyrouge/utils
# copying build/lib/pyrouge/utils/sentence_splitter.py -> build/bdist.linux-x86_64/egg/pyrouge/utils
# ...

# %%
isColab = 'google.colab' in str(get_ipython())
print(isColab)

if isColab:
  import json
  from google.oauth2 import service_account
  from google.cloud.storage import client
  import zipfile
  import shutil

  SERVICE_ACCOUNT = json.loads(r"""{
    "type": "service_account",
    "project_id": "phd-thesis-296814",
    "private_key_id": "42195a69cd47355c121defb0f69ea6ae84d4e374",
    "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
    "client_email": "phd-access-account@phd-thesis-296814.iam.gserviceaccount.com",
    "client_id": "118280957396588864697",
    "auth_uri": "https://accounts.google.com/o/oauth2/auth",
    "token_uri": "https://oauth2.googleapis.com/token",
    "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
    "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/phd-access-account%40phd-thesis-296814.iam.gserviceaccount.com"
  }""")

  BUCKET = "phd-eu-laws"

  credentials = service_account.Credentials.from_service_account_info(
      SERVICE_ACCOUNT,
      scopes=["https://www.googleapis.com/auth/cloud-platform"],
  )

  client = client.Client(
      credentials=credentials,
      project=credentials.project_id,
  )

  def save_file(local_filename, remote_filename):
    bucket = client.get_bucket(BUCKET)
    blob = bucket.blob(remote_filename)
    blob.upload_from_filename(local_filename)

  def download_file(local_filename, remote_filename):
    bucket = client.get_bucket(BUCKET)
    blob = bucket.blob(remote_filename)
    blob.download_to_filename(local_filename)

  def unzip_file(path_to_zip_file, directory_to_extract_to):
    with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
        zip_ref.extractall(directory_to_extract_to)

  def make_archive(source, destination):
      base = os.path.basename(destination)
      name = base.split('.')[0]
      format = base.split('.')[1]
      archive_from = os.path.dirname(source)
      archive_to = os.path.basename(source.strip(os.sep))
      print(source, destination, archive_from, archive_to)
      shutil.make_archive(name, format, archive_from, archive_to)
      shutil.move('%s.%s'%(name,format), destination)
# Out:
# True

# %%
if isColab:
  download_file("PreSumm_src.zip","PreSumm_src.zip")
  unzip_file("PreSumm_src.zip", "Presumm")
  # unzip_file("PreSumm_legal.zip", "../")

# %%
import os
import datetime

# %%
if not os.path.exists('../pretrained_files'):
    os.makedirs('../pretrained_files')

if not os.path.exists('../pretrained_files/models'):
    os.makedirs('../pretrained_files/models')

if not os.path.exists('../pretrained_files/logs'):
    os.makedirs('../pretrained_files/logs')

# %%
  download_file("bert.zip","pretrained_files/bert.zip")
  unzip_file("bert.zip", "../pretrained_files/")

# %%
# !pip3 install transformers
# !pip3 install pytorch-transformers
# Out:
# ...
#      |████████████████████████████████| 1.8MB 11.2MB/s
# ...
#      |████████████████████████████████| 2.9MB 23.6MB/s
# ...
#      |████████████████████████████████| 890kB 39.1MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=28019a6e9a687bb5f92fda9db981e748e36846b41be18b3d7727860c3c907d7d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 184kB 12.0MB/s
# ...
#      |████████████████████████████████| 1.2MB 11.8MB/s
# ...
#      |████████████████████████████████| 133kB 42.4MB/s
# ...
#      |████████████████████████████████| 71kB 8.7MB/s
# ...
#      |████████████████████████████████| 7.2MB 43.3MB/s
# ...
# ERROR: botocore 1.19.54 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...

# %%
# !pip3 install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 11.2MB/s
# ...

# %%
# %cd ../src
# Out:
# [Errno 2] No such file or directory: '../src'
# /content

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/src/"train.py  -task abs -mode train -train_steps 36 -save_checkpoint_steps 3 -warmup_steps_bert 20 -warmup_steps_dec 10 -bert_data_path /pretrained_files/bert/temp -dec_dropout 0.2  -model_path /pretrained_files/models/abstractive -sep_optim true -lr_bert 0.002 -lr_dec 0.2 -batch_size 140 -report_every 100 -accum_count 5 -use_bert_emb true -use_interval true -max_pos 512 -visible_gpus 0  -log_file /pretrained_files/logs/abs_bert
# Out:
# [2021-01-14 11:02:33,289 INFO] Namespace(accum_count=5, alpha=0.6, batch_size=140, beam_size=5, bert_data_path='/pretrained_files/bert/temp', beta1=0.9, beta2=0.999, block_trigram=True, dec_dropout=0.2, dec_ff_size=2048, dec_heads=8, dec_hidden_size=768, dec_layers=6, enc_dropout=0.2, enc_ff_size=512, enc_hidden_size=512, enc_layers=6, encoder='bert', ext_dropout=0.2, ext_ff_size=2048, ext_heads=8, ext_hidden_size=768, ext_layers=2, finetune_bert=True, generator_shard_size=32, gpu_ranks=[0], label_smoothing=0.1, large=False, load_from_extractive='', log_file='/pretrained_files/logs/abs_bert', lr=1, lr_bert=0.002, lr_dec=0.2, max_grad_norm=0, max_length=150, max_pos=512, max_tgt_len=140, min_length=15, mode='train', model_path='/pretrained_files/models/abstractive', optim='adam', param_init=0, param_init_glorot=True, recall_eval=False, report_every=100, report_rouge=True, result_path='../results/cnndm', save_checkpoint_steps=3, seed=666, sep_optim=True, share_emb=False, task='abs', te
# ...

# %%
if isColab:
  model_couples = [
    ('model_step_3.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_6.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_9.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_12.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_15.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_18.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_21.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_24.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_27.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_30.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_33.pt', 'abstractive2020-12-23_14:13:14'),
    ('model_step_36.pt', 'abstractive2020-12-23_14:13:14')
  ]
  for couple in model_couples:
    download_file("../pretrained_files/models/" + couple[0], "pretrained_files/models/" + couple[1] + couple[0])

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/src/"train.py -task abs -mode train -train_from /pretrained_files/models/abstractive/model_step_36.pt -bert_data_path /pretrained_files/bert/temp -dec_dropout 0.2  -model_path /pretrained_files/models/abstractive -train_steps 1000 -save_checkpoint_steps 500 -warmup_steps_bert 200 -warmup_steps_dec 100 -sep_optim true -lr_bert 0.002 -lr_dec 0.2 -batch_size 140 -report_every 100 -accum_count 5 -use_bert_emb true -use_interval true -max_pos 512 -visible_gpus 0  -log_file /pretrained_files/logs/abs_bert
# Out:
# [2021-01-13 23:03:21,865 INFO] Namespace(accum_count=5, alpha=0.6, batch_size=140, beam_size=5, bert_data_path='/pretrained_files/bert/temp', beta1=0.9, beta2=0.999, block_trigram=True, dec_dropout=0.2, dec_ff_size=2048, dec_heads=8, dec_hidden_size=768, dec_layers=6, enc_dropout=0.2, enc_ff_size=512, enc_hidden_size=512, enc_layers=6, encoder='bert', ext_dropout=0.2, ext_ff_size=2048, ext_heads=8, ext_hidden_size=768, ext_layers=2, finetune_bert=True, generator_shard_size=32, gpu_ranks=[0], label_smoothing=0.1, large=False, load_from_extractive='', log_file='/pretrained_files/logs/abs_bert', lr=1, lr_bert=0.002, lr_dec=0.2, max_grad_norm=0, max_length=150, max_pos=512, max_tgt_len=140, min_length=15, mode='train', model_path='/pretrained_files/models/abstractive', optim='adam', param_init=0, param_init_glorot=True, recall_eval=False, report_every=100, report_rouge=True, result_path='../results/cnndm', save_checkpoint_steps=500, seed=666, sep_optim=True, share_emb=False, task='abs', 
# ...

# %%
# !zip -r "PreSumm_legal.zip" "/PreSumm"

# %%
  archive_prefix = '{date:%Y-%m-%d_%H:%M:%S}'.format( date=datetime.datetime.now() )
  steps = [50000, 100000]
  mode = 'abstractive'

  for step in steps:
    model_file_name = 'model_step_' + str(step) + '.pt'
    save_file('../pretrained_files/models/' + mode + '/' + model_file_name, 'pretrained_files/models/' + mode + archive_prefix + model_file_name)

# %%
# %rm ../pretrained_files/bert/temp.test.0.bert.pt
# %mv ../pretrained_files/bert/temp.valid.0.bert.pt ../pretrained_files/bert/temp.test.0.bert.pt

# %%
# %rm -r ../pretrained_files/bert

# %%
if isColab:
  unzip_file("../content/bert.zip", "../pretrained_files/")

# %%
for i in 3000 6000 9000 12000 15000 18000 21000 24000 27000 30000 33000 36000 50000 100000
do
  python3 train.py -task abs -mode test -test_from /pretrained_files/models/model_step_${i}.pt -result_path /pretrained_files/logs/test_abs_bert_results -model_path /pretrained_files/models -batch_size 100 -test_batch_size 50 -bert_data_path /pretrained_files/bert/temp -log_file /pretrained_files/logs/test_abs_bert_log -sep_optim true -use_interval true -visible_gpus 0 -max_pos 512 -max_length 200 -alpha 0.95 -min_length 50
done

# %%
if isColab:
  date_prefix = '{date:%Y-%m-%d_%H:%M:%S}'.format( date=datetime.datetime.now() )
  prefix_mode = 'test'

  for step in [3000, 6000, 9000, 12000, 15000, 18000, 21000, 24000, 27000, 30000, 33000, 36000, 50000, 100000]:
    logs_file_name_prefix = prefix_mode + '_abs_bert_results.' + str(step) + '.'
    for mode in ['gold', 'candidate']:
      logs_file_name = logs_file_name_prefix + mode
      save_file('../pretrained_files/logs/' + logs_file_name, 'pretrained_files/logs/' + date_prefix + logs_file_name)
